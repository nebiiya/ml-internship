# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nebiiya/ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# My chosen lane is *Lane 2: Refresh / Content Opportunity Scoring*. For content editors deciding which web pages needs an update, we will build a ranked scoring system from observable search and enagagement data, predicting the priority queue of a page refresh. A plain baseline rule may fail to capture nuanced signals of actual decay.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
#  This work will improve how we determine which page should a human editor review first. A human content reviewer will use the ranked queue to prioritize their limited time to inspect flagged pages and updating the content if necessary. The cost of a wrong recommendation is wasted human capacity, tanking a healthy page at the top of the queue means wasting hours of analysis, while a page that is genuinely losing traffic is ignored.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# Looking at the starter dataset, we have exactly 30,000 web pages to analyze. A hand-written rule only correctly identifies declining pages 24% of the time in the top 50 (Precision@50: 0.240), while a learned ML model drastically improves this to 74% (Precision@50: 0.740). This improvement proves that this lane is worth pursuing to optimize human review time.

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)

    print("Run ML pipeline to generate model_results.json")
    subprocess.run([sys.executable, "scripts/run_all.py"], check=True)
else:
    # find the repo root from wherever this kernel started
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

    # generate the JSON locally if missing
    if not os.path.exists("outputs/model_results.json"):
      print("Tunning ML pipeline to generate model_results.json")
      subprocess.run([sys.executable, "scripts/run_all.py"], check=True)

# Load the dataset and extract the basic numbers
import pandas as pd
import json

# Show the scale of the problem (30,000 individual web pages)
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(f"Total pages to analyze: {df.shape[0]}")

# Show the baseline vs ML gap (from the pipeline output)
res = json.load(open("outputs/model_results.json"))
base = res["baseline"]["baseline_precision_at_50"]
rf = res["models"]["random_forest"]["precision_at_50"]

print(f"Hand-written rule Precision@50: {base: .3f}")
print(f"Random Forest Precision@50: {rf: .3f}")
print(f"Improvement: {rf/base: .1f}x")
# Out:
# Run ML pipeline to generate model_results.json
# Total pages to analyze: 30000
# Hand-written rule Precision@50:  0.240
# Random Forest Precision@50:  0.740
# Improvement:  3.1x

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# I will claim only directional, decision-support results. This model ranks the observed likelihood that a page needs an update based on historical search signals to support priorization. I cannot claim causal proof (no guarantee that editing a flagged page will restore traffic). Finally, I cannot claim that this model is "predicting Google's algorithm."

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ / ] Every section above is filled — markdown thinking AND the code that backs it
# - [ / ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ / ] No client names, URLs, or private queries anywhere
# - [ / ] My claims use careful words: observed, measured, directional, decision-support
# - [ / ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
